# %% [markdown]
# # Introduction
# In this notebook, we will clean the dataset and make it ready for analysis.

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
# Data manipulation
import pandas as pd
import numpy as np

#Visualization
import matplotlib.pyplot as plt
import seaborn as sb

from src.preprocess.build_features import merge_dataset
from src.visualization.viz import count_plot, bar_count_plot, bar_sum_plot

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Loading the Datasets

# %%
items = pd.read_csv('../data/raw/items.csv')
reviews = pd.read_csv('../data/raw/reviews.csv')

# %%
items.head()
# Out:
#          asin     brand                                              title  \
# 0  B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1  B0009N5L7K  Motorola                                Motorola I265 phone
# 2  B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3  B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4  B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
#
#                                                  url  \
# 0  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1  https://www.amazon.com/Motorola-i265-I265-phon...
# 2  https://www.amazon.com/MOTOROLA-C168i-CINGULAR...
# 3  https://www.amazon.com/Nokia-6500-Slide-silver...
# 4  https://www.amazon.com/Motorola-i335-Phone-Boo...
#
#                                                image  rating  \
# 0  https://m.media-amazon.com/images/I/2143EBQ210...     3.0
# 1  https://m.media-amazon.com/images/I/419WBAVDAR...     2.9
# ...

# %%
reviews.head()
# Out:
#          asin           name  rating               date  verified  \
# 0  B0000SX2UC          Janet       3   October 11, 2005     False
# 1  B0000SX2UC     Luke Wyatt       1    January 7, 2004     False
# 2  B0000SX2UC         Brooke       5  December 30, 2003     False
# 3  B0000SX2UC  amy m. teague       3     March 18, 2004     False
# 4  B0000SX2UC  tristazbimmer       4    August 28, 2005     False
#
#                                           title  \
# 0                   Def not best, but not worst
# 1                   Text Messaging Doesn't Work
# 2                               Love This Phone
# 3                       Love the Phone, BUT...!
# 4  Great phone service and options, lousy case!
#
#                                                 body  helpfulVotes
# 0  I had the Samsung A600 for awhile which is abs...           1.0
# 1  Due to a software issue between Nokia and Spri...          17.0
# 2  This is a great, reliable phone. I also purcha...           5.0
# ...

# %% [markdown]
# ### Items grouped by Brand

# %%
count_plot(data=items, feature='brand', color='xkcd:soft green')

# %% [markdown]
# ### Average Overall Rating of Brands

# %%
bar_count_plot(data=items, feature1='brand', feature2='rating', title="Average Rating Per Brand", color='xkcd:coral' )

# %%
bar_sum_plot(data=items, feature1='brand', feature2='totalReviews', title="Total Reviews Per Brand", color='g' )

# %%
ax = items.groupby("brand").sum()['totalReviews'].plot(kind="barh", figsize=(12, 8), title="Total Reviews Per Brand", color='g')

# %%
items[items.brand=='ASUS'].totalReviews.sum()
# Out:
# 504

# %% [markdown]
# ### Merging both the datasets based on asin attribute

# %%
product_reviews = merge_dataset(items, reviews, on='asin')
product_reviews.head()
# Out:
#          asin  brand                                            title_x  \
# 0  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 2  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 3  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 4  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
#
#                                                  url  \
# 0  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 2  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 3  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 4  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
#
#                                                image  rating_x  \
# 0  https://m.media-amazon.com/images/I/2143EBQ210...       3.0
# 1  https://m.media-amazon.com/images/I/2143EBQ210...       3.0
# ...

# %%
product_reviews.rename(columns={"rating_x": "rating", "title_x": "title", "title_y": "product_title", "rating_y": "overall_rating"}, inplace=True)

# %%
product_reviews.head()
# Out:
#          asin  brand                                              title  \
# 0  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 2  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 3  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 4  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
#
#                                                  url  \
# 0  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 2  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 3  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 4  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
#
#                                                image  rating  \
# 0  https://m.media-amazon.com/images/I/2143EBQ210...     3.0
# 1  https://m.media-amazon.com/images/I/2143EBQ210...     3.0
# ...

# %% [markdown]
# ### Drop unnecessary columns

# %%
final_product_reviews = product_reviews.drop(columns=['url', 'image', 'reviewUrl', 'name'])
final_product_reviews.head()
# Out:
#          asin  brand                                              title  \
# 0  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 2  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 3  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 4  B0000SX2UC  Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
#
#    rating  totalReviews prices  overall_rating               date  verified  \
# 0     3.0            14    NaN               3   October 11, 2005     False
# 1     3.0            14    NaN               1    January 7, 2004     False
# 2     3.0            14    NaN               5  December 30, 2003     False
# 3     3.0            14    NaN               3     March 18, 2004     False
# 4     3.0            14    NaN               4    August 28, 2005     False
#
#                                   product_title  \
# ...

# %% [markdown]
# ### Using Verified Reviews

# %%
final_product_reviews = final_product_reviews[final_product_reviews.verified == True]

# %%
final_product_reviews.shape
# Out:
# (75565, 12)

# %% [markdown]
# ### Remove Records where Body is Null

# %%
final_product_reviews = final_product_reviews[~final_product_reviews['body'].isnull()]
